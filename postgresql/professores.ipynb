# %% [markdown]
# # Importação das Bibliotecas utilizadas no projeto

# %%
import pandas as pd
import psycopg2 as pg
from sqlalchemy import create_engine

# %% [markdown]
# # Criando a conexão engine com o Postgresql

# %%
engine = create_engine('postgresql://postgres:2345678@localhost:5432/faculdade')

# %% [markdown]
# # Criando a conexão com o banco de dados

# %%
conexao = pg.connect(user = 'postgres', password = '2345678', host = 'localhost', port = '5432', database = 'faculdade')

# %% [markdown]
# # Criando o cursor que faz as ações com o banco de dados

# %%
cur = conexao.cursor()

# %% [markdown]
# # Selecionando todos os registros da tabela de professores

# %%
sql = "select * from professores"

# %% [markdown]
# # Passando a tabela de professores para um DataFrame

# %%
professores_df = pd.read_sql(sql, con=engine)

# %% [markdown]
# # Exibindo a tabela professores no Python|

# %%
professores_df
# Out:
#     cod_prof  cod_curso           nom_prof email
# 0        103         10             GENARO  None
# 1         11         26           DOMINGOS  None
# 2       1128         10            NILDETE  None
# 3        114         10          FREDERICO  None
# 4       1148         26               JOSe  None
# 5       1149         10               HUGO  None
# 6       1150         10            GABRIEL  None
# 7        118         10             GERSON  None
# 8         12         10             ANDReS  None
# 9        121         10          MARGARIDA  None
# 10        13         10            MARCELO  None
# 11       135         10              NOEMI  None
# 12       143         10              MARCO  None
# 13       145         26              EDSON  None
# 14        15         10              FaBIO  None
# 15      1508         26            JUGURTA  None
# 16        16         10           RAIMUNDO  None
# 17      1689         10             DANTAS  None
# 18      1691         10            KELLYNE  None
# 19        17         26             CARLOS  None
# 20      1728         10               ALAN  None
# 21       176         10              ISMAR  None
# 22       178         10               JOaO  None
# 23       186         10             GILVAN  None
# 24       189         26           VIRGILIO  None
# 25       196         10            EDUARDO  None
# 26       197         10               JOSe  None
# 27       202         10              MaRIO  None
# 28      2028         10              OTHON  None
# 29       203         10            JAILSON  None
# 30       205         10               JOSe  None
# 31       215         10               JOaO  None
# 32       216         10             DANILO  None
# 33       218         26  JOSe ALVES VIEIRA  None
# 34      2228         10            CLAUDIO  None
# 35       225         26             SHEILA  None
# 36       226         26             MARCOS  None
# 37       232         10            RODRIGO  None
# 38       234         10          METHANIAS  None
# 39       235         10            EDUARDO  None
# 40      2375         10               LEVI  None
# 41       238         10               ALEX  None
# 42       240         26              SoNIA  None
# 43       241          3          FRANCISCO  None
# 44      2428         10            EDUARDO  None
# 45       250         10          HORTeNCIA  None
# 46      2548         10              MARIA  None
# 47        30         10              MARIA  None
# 48      3288         10            ESTRELA  None
# 49        33         10                ANA  None
# 50        34         10         CHRISTIANE  None
# 51         4         10         CHRISTIANE  None
# 52       502         10              EXSON  None
# 53        58         10         ALESSANDRA  None
# 54       770         10             WANUSA  None
# 55       888         26            ANToNIO  None
# 56       930         10          FRANCISCO  None
# 57        97         10              JULIO  None

# %%
professores_df.loc[professores_df['cod_prof'] == 770]
# Out:
#     cod_prof  cod_curso nom_prof email
# 54       770         10   WANUSA  None
